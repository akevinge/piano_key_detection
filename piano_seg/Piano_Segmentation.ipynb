# %%
# !pip install ultralytics roboflow --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 42.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 8.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 21.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 70.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 120.2 MB/s eta 0:00:00

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, random_split
from torchvision import transforms, models
import torch.optim as optim

transform = transforms.Compose(
    [
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ]
)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)
model.load_state_dict(torch.load("resnet_piano_key.pth"))
num_features = model.fc.in_features
model.fc = nn.Linear(num_features, 1)  # single output for binary classification
model = model.to(device)

# %%
from roboflow import Roboflow

# Replace with your Roboflow credentials
ROBOFLOW_API_KEY=""
WORKSPACE_NAME=""
PROJECT_NAME=""
rf = Roboflow(api_key=ROBOFLOW_API_KEY)
project = rf.workspace(WORKSPACE_NAME).project(PROJECT_NAME)
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to piano-original-1 in yolov8:: 100%|██████████| 1153/1153 [00:00<00:00, 6938.62it/s]
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
from ultralytics import YOLO

model = YOLO("yolov8n-seg.pt")
model.train(
    data=dataset.location + "/data.yaml",  # automatically points to Roboflow dataset
    epochs=50,
    imgsz=640,
    batch=8,
    project="piano_detect_yolov8",
    name="train",
    task="segment"  # 'detect' for object detection, 'segment' for segmentation datasets
)
# Out:
# ...
# Ultralytics 8.3.228 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
results = model.predict(source="image.png", save=True, show=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2534540109.py in <cell line: 0>()
# ----> 1 results = model.predict(source="image.png", save=True, show=False)
#
# NameError: name 'model' is not defined

# %%
path = "/content/piano_detect_yolov8/train2/weights/best.pt"
model = YOLO(path, task="segment")
results = model.predict(source="image.png", save=True, show=False)
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# /tmp/ipython-input-84353977.py in <cell line: 0>()
#       2 path = "/content/piano_detect_yolov8/train2/weights/best.pt"
#       3 model = YOLO(path, task="segment")
# ----> 4 checkpoint = torch.load(path, weights_only=True)
#       5 print(checkpoint.keys())
#       6 print(checkpoint['model'].names)  # Check class names
#
# /usr/local/lib/python3.12/dist-packages/torch/serialization.py in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1527                         )
#    1528                     except pickle.UnpicklingError as e:
# -> 1529                         raise pickle.UnpicklingError(_get_wo_message(str(e))) from None
#    1530                 return _load(
#    1531                     opened_zipfile,
#
# ...
